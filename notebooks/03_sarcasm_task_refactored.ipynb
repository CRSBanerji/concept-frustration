# %% [markdown]
# # Sarcasm task (refactored)
#
# This notebook is a lightweight runner for the refactored package.

# %%
import sys
from pathlib import Path

repo_root = Path.cwd().resolve().parent
src_path = repo_root / 'src'
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from sarcasm_task.experiment import main

# %%
main()
